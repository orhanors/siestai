# %%
import os
#print(os.environ["OPENAI_API_KEY"])

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-large",
    # With the `text-embedding-3` class
    # of models, you can specify the size
    # of the embeddings you want returned.
    # dimensions=1024
)

# %%
# This demonstrates how vector stores enable semantic search - the search query 
# "What is LangChain?" doesn't match the text exactly, but the vector embeddings 
# capture the semantic meaning, allowing the system to find the relevant information.

# Create a vector store with a sample text
from langchain_core.vectorstores import InMemoryVectorStore

text = "LangChain is the framework for building context-aware reasoning applications"

vectorstore = InMemoryVectorStore.from_texts(
    [text],
    embedding=embeddings,
)

# Use the vectorstore as a retriever
retriever = vectorstore.as_retriever()

# Retrieve the most similar text
retrieved_documents = retriever.invoke("What is LangChain?")

# show the retrieved document's content
retrieved_documents[0].page_content
# Out:
# {'ca223858-581e-4d34-8d2c-1ec8e4a56918': {'id': 'ca223858-581e-4d34-8d2c-1ec8e4a56918', 'vector': [-0.019244952127337456, 0.0037762185093015432, -0.03293963521718979, 0.0037592509761452675, 0.0081217922270298, -0.012525808997452259, -0.009765757247805595, 0.02135646715760231, -0.015368813648819923, 0.0018796254880726337, 0.02052694372832775, 0.022427307441830635, -0.023256830871105194, -0.015263237990438938, -0.005029930733144283, -0.007360138464719057, -0.034478023648262024, 0.00016519778000656515, 0.021371548995375633, -0.01253334991633892, -0.02005939371883869, 0.02751002460718155, -0.03924401476979256, 0.030375652015209198, 0.030375652015209198, -0.021733522415161133, 0.03257765993475914, -0.021130234003067017, -0.025926388800144196, 0.018867895007133484, 0.034236710518598557, -0.013340250588953495, 0.0038026124238967896, -0.02141679637134075, 0.0012697370257228613, -0.05565350502729416, 0.0510684996843338, 0.002530047670006752, -0.019139375537633896, 0.003761136205866933, 0.0008
# ...
